# %%
import csv
import os

# %%
election_data = ["election_data_1", "election_data_2"]

election_dataCSV = os.path.join('PyPoll/','raw_data/' + str(election_data) + '.csv')
election_resultsCSV = os.path.join('PyPoll','output/' + str(election_data) + '.csv')

# %%
with open(election_dataCSV, 'r') as csvfile:
    
    csvreader = csv.reader(csvfile, delimiter=',')

    next(csvreader, None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-111167ef3935> in <module>()
# ----> 1 with open(election_dataCSV, 'r') as csvfile:
#       2
#       3     csvreader = csv.reader(csvfile, delimiter=',')
#       4
#       5     next(csvreader, None)
#
# FileNotFoundError: [Errno 2] No such file or directory: "PyPoll/raw_data/['election_data_1', 'election_data_2'].csv"
